# %%
import torchvision

# 指定 transform 将把原本是 PIL Image 格式的数据转为 PyTorch 需要的 Tensor 格式
train_data = torchvision.datasets.CIFAR10(root="./dataset", train=True, transform=torchvision.transforms.ToTensor(), download=True)
test_data = torchvision.datasets.CIFAR10(root="./dataset", train=False, transform=torchvision.transforms.ToTensor(), download=True)

# length 长度
train_data_length = len(train_data)
test_data_length = len(test_data)

# 如果train_data_length = 10, 则训练数据集的长度为10
print("训练数据集的长度为：{}".format(train_data_length))
print("测试数据集的长度为：{}".format(test_data_length))
# 也可以使用f-string的方式来打印长度
# print(f"训练数据集的长度: {train_data_length}")
# print(f"测试数据集的长度: {test_data_length}")

# 利用 DataLoader 来加载数据集
from torch.utils.data import DataLoader
train_dataloader = DataLoader(train_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=False)


from P27_model import *
# 创建神经网络模型
net = Net()

# 损失函数
import torch.nn as nn
loss_fn = nn.CrossEntropyLoss()

# 优化器
# leaning_rate = 0.01

learning_rate = 0.01
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate)

# 设置训练参数
# 记录训练的次数
total_train_step = 0
# 记录测试的次数
total_test_step = 0
# 训练的轮数
epoch = 10

# 添加tensorboard
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter("logs")

import os
# 确保保存模型的文件夹存在，如果不存在则自动创建
os.makedirs("models", exist_ok=True)

for i in range(epoch):
    print("第 {} 轮训练开始".format(i+1))
    
    # 按照之前的优化建议，将 net.train() 提到了每个 epoch 循环一开始
    net.train()
    
    # 训练步骤开始
    for data in train_dataloader:
        # data 是一个列表，包含了训练数据和对应的标签
        images, labels = data
        
        # 将输入数据传入神经网络模型，得到输出结果
        outputs = net(images)
        # 计算损失函数的值
        loss = loss_fn(outputs, labels)
        # 优化器清零
        optimizer.zero_grad()   
        # 反向传播，计算梯度
        loss.backward()
        # 更新参数
        optimizer.step()
        total_train_step += 1
        if total_train_step % 100 == 0:
            print("训练次数: {}, Loss: {}".format(total_train_step, loss.item()))
            writer.add_scalar("train_loss", loss.item(), total_train_step)
            # 记录训练的次数和损失值到 TensorBoard 中，方便后续可视化分析


    # 测试步骤开始
    with torch.no_grad():   # 在测试阶段，我们不需要计算梯度，因此使用 torch.no_grad() 来禁用梯度计算
        net.eval()  # 将模型设置为评估模式
        total_test_loss = 0
        total_accuracy = 0
        for data in test_dataloader:
            images, labels = data
            outputs = net(images)
            loss = loss_fn(outputs, labels)
            total_test_loss += loss.item()
            # 计算准确率
            accuracy = (outputs.argmax(dim=1) == labels).sum().item()  # 计算当前批次中预测正确的数量
            total_accuracy += accuracy  # 累加预测正确的数量
            # _, predicted = torch.max(outputs.data, 1)  # 获取输出结果中概率最大的类别索引
            # total_accuracy += (predicted == labels).sum().item()  # 计算预测正确的数量
    print("整体测试集上的Loss: {}".format(total_test_loss))
    print("整体测试集上的准确率: {}%".format(total_accuracy / test_data_length * 100))
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    writer.add_scalar("test_accuracy", total_accuracy / test_data_length, total_test_step)
    total_test_step += 1

    # 每个 epoch 结束后保存一次模型，路径指向 models 文件夹
    torch.save(net, "./models/net_{}.pth".format(i+1))
    # torch.save(net.state_dict(), "./models/net_{}_state_dict.pth".format(i+1))    仅保存模型参数
    print("模型已保存至 ./models/net_{}.pth".format(i+1))

writer.close()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练数据集的长度为：50000
# 测试数据集的长度为：10000
# 第 1 轮训练开始
# 训练次数: 100, Loss: 2.30057692527771
# 训练次数: 200, Loss: 2.2952818870544434
# 训练次数: 300, Loss: 2.2502524852752686
# 训练次数: 400, Loss: 2.170952558517456
# 训练次数: 500, Loss: 1.9710413217544556
# 训练次数: 600, Loss: 2.1027634143829346
# 训练次数: 700, Loss: 1.8425326347351074
# 整体测试集上的Loss: 307.7322016954422
# 整体测试集上的准确率: 29.599999999999998%
# 模型已保存至 ./models/net_1.pth
# 第 2 轮训练开始
# 训练次数: 800, Loss: 2.1216025352478027
# 训练次数: 900, Loss: 1.8604357242584229
# 训练次数: 1000, Loss: 1.7790021896362305
# 训练次数: 1100, Loss: 1.8983126878738403
# 训练次数: 1200, Loss: 1.568321943283081
# 训练次数: 1300, Loss: 1.7706847190856934
# 训练次数: 1400, Loss: 1.8523240089416504
# 训练次数: 1500, Loss: 2.093268632888794
# 整体测试集上的Loss: 288.050012588501
# 整体测试集上的准确率: 34.36%
# 模型已保存至 ./models/net_2.pth
# 第 3 轮训练开始
# 训练次数: 1600, Loss: 1.7056978940963745
# 训练次数: 1700, Loss: 1.7990901470184326
# 训练次数: 1800, Loss: 1.6698455810546875
# 训练次数: 1900, Loss: 1.6675201654434204
# 训练次数: 2000, Loss: 1.8534044027328491
# 训练次数: 2100, Loss: 1.6419700384140015
# 训练次数: 2200, Loss: 1.4894828796386719
# 训练次数: 2300, Loss: 1.4140639305114746
# 整体测试集上的Loss: 252.8829755783081
# 整体测试集上的准确率: 42.67%
# 模型已保存至 ./models/net_3.pth
# 第 4 轮训练开始
# 训练次数: 2400, Loss: 1.4840576648712158
# 训练次数: 2500, Loss: 1.5798828601837158
# 训练次数: 2600, Loss: 1.611621618270874
# 训练次数: 2700, Loss: 1.7355393171310425
# 训练次数: 2800, Loss: 1.3089426755905151
# 训练次数: 2900, Loss: 1.3592966794967651
# 训练次数: 3000, Loss: 1.5870144367218018
# 训练次数: 3100, Loss: 1.5394166707992554
# 整体测试集上的Loss: 267.7153571844101
# 整体测试集上的准确率: 39.53%
# 模型已保存至 ./models/net_4.pth
# 第 5 轮训练开始
# 训练次数: 3200, Loss: 1.335135817527771
# 训练次数: 3300, Loss: 1.4450000524520874
# 训练次数: 3400, Loss: 1.403869390487671
# 训练次数: 3500, Loss: 1.596083641052246
# 训练次数: 3600, Loss: 1.4027806520462036
# 训练次数: 3700, Loss: 1.2413519620895386
# 训练次数: 3800, Loss: 1.5029512643814087
# 训练次数: 3900, Loss: 1.34172785282135
# 整体测试集上的Loss: 222.31196582317352
# 整体测试集上的准确率: 49.370000000000005%
# 模型已保存至 ./models/net_5.pth
# 第 6 轮训练开始
# 训练次数: 4000, Loss: 1.2487951517105103
# 训练次数: 4100, Loss: 1.2619825601577759
# 训练次数: 4200, Loss: 1.5334525108337402
# 训练次数: 4300, Loss: 1.4721285104751587
# 训练次数: 4400, Loss: 1.3759515285491943
# 训练次数: 4500, Loss: 1.3906015157699585
# 训练次数: 4600, Loss: 1.1156070232391357
# 整体测试集上的Loss: 223.9717494249344
# 整体测试集上的准确率: 49.09%
# 模型已保存至 ./models/net_6.pth
# 第 7 轮训练开始
# 训练次数: 4700, Loss: 1.4956883192062378
# 训练次数: 4800, Loss: 1.4751110076904297
# 训练次数: 4900, Loss: 1.2813493013381958
# 训练次数: 5000, Loss: 1.146054744720459
# 训练次数: 5100, Loss: 1.492533802986145
# 训练次数: 5200, Loss: 1.3254673480987549
# 训练次数: 5300, Loss: 1.336302399635315
# 训练次数: 5400, Loss: 1.4173387289047241
# 整体测试集上的Loss: 216.5345664024353
# 整体测试集上的准确率: 51.31%
# 模型已保存至 ./models/net_7.pth
# 第 8 轮训练开始
# 训练次数: 5500, Loss: 1.1568177938461304
# 训练次数: 5600, Loss: 1.3687899112701416
# 训练次数: 5700, Loss: 1.194558024406433
# 训练次数: 5800, Loss: 1.1423741579055786
# 训练次数: 5900, Loss: 1.2180349826812744
# 训练次数: 6000, Loss: 1.156274437904358
# 训练次数: 6100, Loss: 1.2726975679397583
# 训练次数: 6200, Loss: 1.2620598077774048
# 整体测试集上的Loss: 200.06859862804413
# 整体测试集上的准确率: 55.11000000000001%
# 模型已保存至 ./models/net_8.pth
# 第 9 轮训练开始
# 训练次数: 6300, Loss: 1.2917847633361816
# 训练次数: 6400, Loss: 1.4166641235351562
# 训练次数: 6500, Loss: 1.330566644668579
# 训练次数: 6600, Loss: 1.1736369132995605
# 训练次数: 6700, Loss: 1.1320526599884033
# 训练次数: 6800, Loss: 1.084415316581726
# 训练次数: 6900, Loss: 1.2627257108688354
# 训练次数: 7000, Loss: 1.3519158363342285
# 整体测试集上的Loss: 199.80324631929398
# 整体测试集上的准确率: 54.83%
# 模型已保存至 ./models/net_9.pth
# 第 10 轮训练开始
# 训练次数: 7100, Loss: 1.4395966529846191
# 训练次数: 7200, Loss: 1.2296168804168701
# 训练次数: 7300, Loss: 1.042248010635376
# 训练次数: 7400, Loss: 0.9081507921218872
# 训练次数: 7500, Loss: 0.9724593162536621
# 训练次数: 7600, Loss: 1.182634711265564
# 训练次数: 7700, Loss: 1.0549442768096924
# 训练次数: 7800, Loss: 1.1279240846633911
# 整体测试集上的Loss: 210.48627042770386
# 整体测试集上的准确率: 53.42%
# 模型已保存至 ./models/net_10.pth
