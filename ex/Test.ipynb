# %%
print("hello world")
# Out:
# hello world

# %%
print("Start")
a = "Hello, World!"
b = "2019"
c = a + b   
print(c)
# Out:
# Start
# Hello, World!2019

# %%
import torch
import torchvision

image_path
