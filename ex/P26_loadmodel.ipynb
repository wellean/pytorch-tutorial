# %%
import torch

# 方式1：加载整个模型
model1 = torch.load("models/vgg16.pth")
#print(model1)

# 方式2：加载模型的状态字典
model2 = torch.load("models/vgg16_state_dict.pth")  # 先加载整个模型以获取结构
print(model2)


import torchvision
# 使用状态字典需要先创建一个新的模型实例，然后加载权重
vgg16 = torchvision.models.vgg16(pretrained=False)  # 创建一个新的 VGG16 模型实例
vgg16.load_state_dict(torch.load("models/vgg16_state_dict.pth"))  # 加载预训练的权重
print(vgg16)

# 加载自建模型
# from .. import 需要.py文件且必须放在同一目录下，而.ipynb文件不能导入，因为.ipynb文件不是一个模块，无法被导入，所以只能直接从同一目录下的.py文件中导入类或函数。
from P26_save import Mymodel

mymodel = torch.load("models/mymodel.pth")
print(mymodel)
# Out:
# C:\Users\15807\AppData\Local\Temp\ipykernel_16812\2202867309.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model1 = torch.load("models/vgg16.pth")
# ...
